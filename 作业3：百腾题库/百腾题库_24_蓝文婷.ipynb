# %%
driver=webdriver.Chrome()
url = 'https://pintia.cn/problem-sets/1111652100718116864/problems/type/7'
driver.get(url)
data=[]

# %%
html=driver.page_source
#print(html)

# %%
list=[]
biaoti2=[]
reobj = re.compile(r'<td class=".*?"></td><td>([\s\S]*?)</td><td><a href="([\s\S]*?)" class="">([\s\S]*?)</a></td><td>([\s\S]*?)</td><td>([\s\S]*?)</td><td>([\s\S]*?)</td><td>([\s\S]*?)</td>')
for match in reobj.finditer(html):
    #print(match.group(1),match.group(2),match.group(3),match.group(4),match.group(5),match.group(6),match.group(7))
    biaohao = match.group(1)
    lianjie = 'https://pintia.cn/'+match.group(2)
    biaoti = match.group(3)
    fengshu = match.group(4)
    tongguoshu = match.group(5)
    tijiaoshu = match.group(6)
    tonguolu = match.group(7)
    print(biaohao,'https://pintia.cn/'+lianjie,biaoti,fengshu,tongguoshu,tijiaoshu,tonguolu)
    biaoti2.append(biaoti)
    #match start: match.start()
    #match end (exclusive): match.end()

    
#driver.find_element_by_xpath("//div[@id='sparkling-daydream']/div[3]/div[3]/div/ul/li/a/div").click()
#reobj = re.compile(r'<tr><td class=".*?"></td><td>([\s\S]*?)</td><td><a href="([\s\S]*?)" class="">([\s\S]*?)</a></td><td>([\s\S]*?)</td><td>([\s\S]*?)</td><td>([\s\S]*?)</td><td>([\s\S]*?)</td></tr>')
#for match in reobj.finditer(html):
    #print(match.group(1),match.group(2),match.group(3),match.group(4),match.group(5),match.group(6),match.group(7))
    # match start: match.start()
    # match end (exclusive): match.end()
    # matched text: match.group()
# Out:
# 第1章-1 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653039147499521 从键盘输入两个数，求它们的和并输出 30 4005 10141 0.39
# 第1章-2 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653039147499522 从键盘输入三个数到a,b,c中，按公式值输出 30 3298 13082 0.25
# 第1章-3 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653039147499520 输出“Python语言简单易学” 10 2658 9420 0.28
# 第2章-1 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653447408467981 计算 11+12+13+...+m 30 2974 12385 0.24
# 第2章-2 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653447408467968 计算分段函数[1] 10 2551 11057 0.23
# 第2章-3 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653447408467971 阶梯电价 15 2194 8961 0.24
# 第2章-4 https://pintia.cn/https://pintia.cn//problem-sets/1111652100718116864/problems/1111653447408467975 特殊a串数列求和 20 2171 7172 0.30
# ...

# %%
driver=webdriver.Chrome()
url = 'https://pintia.cn/problem-sets/1111652100718116864/problems/type/6'
driver.get(url)
html2=driver.page_source
#print(html)

# %%
list=[]
biaoti3=[]
reobj = re.compile(r'<td class=".*?"></td><td>([\s\S]*?)</td><td><a href="([\s\S]*?)" class="">([\s\S]*?)</a></td><td>([\s\S]*?)</td><td>([\s\S]*?)</td><td>([\s\S]*?)</td><td>([\s\S]*?)</td>')
for match in reobj.finditer(html2):
    #print(match.group(1),match.group(2),match.group(3),match.group(4),match.group(5),match.group(6),match.group(7))
    biaohao1 = match.group(1)
    lianjie1 = 'https://pintia.cn/'+match.group(2)
    biaoti1 = match.group(3)
    fengshu1 = match.group(4)
    tongguoshu1 = match.group(5)
    tijiaoshu1 = match.group(6)
    tonguolu1 = match.group(7)
    print(biaohao1,'https://pintia.cn/'+lianjie1,biaoti1,fengshu1,tongguoshu1,tijiaoshu1,tonguolu1)
    biaoti3.append(biaoti1)
    #match start: match.start()
    #match end (exclusive): match.end()

# %%
import time
driver.find_element_by_xpath('//*[@id="sparkling-daydream"]/div[3]/div[3]/div/ul/li[1]/a').click()
tixing='函数题'
time.sleep(1)
# Out:
# 第1章-1 /problem-sets/1111652100718116864/problems/1111653039147499521 从键盘输入两个数，求它们的和并输出 30 3814 9572 0.40
# 第1章-2 /problem-sets/1111652100718116864/problems/1111653039147499522 从键盘输入三个数到a,b,c中，按公式值输出 30 3154 12348 0.26
# 第1章-3 /problem-sets/1111652100718116864/problems/1111653039147499520 输出“Python语言简单易学” 10 2534 8922 0.28
# 第2章-1 /problem-sets/1111652100718116864/problems/1111653447408467981 计算 11+12+13+...+m 30 2837 11789 0.24
# 第2章-2 /problem-sets/1111652100718116864/problems/1111653447408467968 计算分段函数[1] 10 2449 10551 0.23
# 第2章-3 /problem-sets/1111652100718116864/problems/1111653447408467971 阶梯电价 15 2098 8469 0.25
# 第2章-4 /problem-sets/1111652100718116864/problems/1111653447408467975 特殊a串数列求和 20 2084 6866 0.30
# 第2章-5 /problem-sets/1111652100718116864/problems/1111653447408467970 求奇数分之一序列前N项和 15 1842 5054 0.36
# 第2章-6 /problem-sets/1111652100718116864/problems/1111653447408467973 求交错序列前N项和 15 1724 3902 0.44
# ...

# %%
def get_data():
    html=driver.page_source
    etr=etree.HTML(html,etree.HTMLParser())
    for tr in etr.xpath('//tbody/tr'):
        biaohao=tr.xpath('td[2]/text()')[0]   
        biaoti=tr.xpath('td[3]/a/text()')[0]  
        fengshu=tr.xpath('td[4]/text()')[0]  
        tongguoshu=tr.xpath('td[5]/text()')[0] 
        tijiaoshu=tr.xpath('td[6]/text()')[0]  
        tongguolv=tr.xpath('td[7]/text()')[0] 
        href='https://pintia.cn'+tr.xpath('td[3]/a/@href')[0]  
        data.append((tixing,biaohao,biaoti,fengshu,tongguoshu,tijiaoshu,tongguolv,href))

# %%
from selenium import webdriver
from lxml import etree
import time
url='https://pintia.cn/problem-sets/1111652100718116864/problems/type/7'
driver=webdriver.Chrome()
driver.get(url)
time.sleep(5)
data=[]

# %%
driver.find_element_by_xpath('//*[@id="sparkling-daydream"]/div[3]/div[3]/div/ul/li[1]/a').click()
tixing='函数题'
time.sleep(1)
get_data()

# %%
driver.find_element_by_xpath('//*[@id="sparkling-daydream"]/div[3]/div[3]/div/ul/li[2]/a').click()
tixing='编程题'
time.sleep(1)
get_data()

# %%
tmlist=[]
for i in data:
    driver.get(i[-1])
    time.sleep(1)
    html=etree.HTML(driver.page_source,etree.HTMLParser())
    tm=html.xpath('//*[@id="sparkling-daydream"]/div[3]/div[3]/div/div[4]/div[2]/div[1]/div/p[1]//text()')
    s=''
    try:
        for i in tm:
            s=s+i.strip()
        tmlist.append((s,driver.page_source))
    except:
        tmlist.append(('',driver.page_source))

# %%
data2=[]
for i in range(len(data)):
    data2.append(data[i]+tmlist[i])

# %%
from pony.orm import *

db = Database()

class Tm(db.Entity):
    id = PrimaryKey(int, auto=True)
    tixing = Optional(str, column='tixing')
    biaohao = Optional(str, column='biaohao')
    biaoti = Optional(str, column='biaoti')
    fengshu = Optional(str, column='fengshu')
    tongguoshu = Optional(str, column='tongguoshu')
    tijiaoshu = Optional(str, column='tijiaoshu')
    tongguolv = Optional(str, default='tongguolv')
    tmneirong = Optional(str, column='tmneirong')
    html = Optional(str, column='html')
    href = Optional(str, column='href')

# %%
db.bind(provider='sqlite', filename=r'D:\code\tm.sqlite')

db.generate_mapping(create_tables=True)

set_sql_debug(True)
# Out:
# GET NEW CONNECTION
# RELEASE CONNECTION
# GET CONNECTION FROM THE LOCAL POOL
# PRAGMA foreign_keys = false
# BEGIN IMMEDIATE TRANSACTION
# SELECT "Tm"."id", "Tm"."tixing", "Tm"."biaohao", "Tm"."biaoti", "Tm"."fengshu", "Tm"."tongguoshu", "Tm"."tijiaoshu", "Tm"."tongguolv", "Tm"."tmneirong", "Tm"."html", "Tm"."href"
# FROM "Tm" "Tm"
# WHERE 0 = 1
#
# COMMIT
# PRAGMA foreign_keys = true
# CLOSE CONNECTION
# RELEASE CONNECTION

# %%
for i in data2:
    s=Tm(tixing=i[0],biaohao=i[1],biaoti=i[2],fengshu=i[3],tongguoshu=i[4],tijiaoshu=i[5],tongguolv=i[6],tmneirong=i[8],html=i[-1],href=i[7])
    db.commit()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Tm" ("tixing", "biaohao", "biaoti", "fengshu", "tongguoshu", "tijiaoshu", "tongguolv", "tmneirong", "html", "href") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# ...
