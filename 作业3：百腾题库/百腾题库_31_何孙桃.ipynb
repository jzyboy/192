# %%
import re,time
from selenium import webdriver
driver=webdriver.Chrome()

#获取源代码
def get_html(url):
    driver.get(url)
    time.sleep(5)
    html=driver.page_source
    return html

#获取标号
def get_bh(html):
    list1=[]
    reobj = re.compile(r'<tr><td class="answerIcon_1du7d"></td><td>([\d\D]*?)</td>')
    for match in reobj.finditer(html):
        bh=match.group(1)
        list1.append(bh)
    return list1

#获取网页链接
def get_lj(html):
    list2=[]
    list3=[]
    reobj = re.compile(r'<td><a href="([\d\D]*?)"')
    for match in reobj.finditer(html):
        lj=match.group(1)
        list2.append(lj)
    for i in list2:
        t="https://pintia.cn"+i
        list3.append(t)
    return list3

#获取标题
def get_bt(html):
    list4=[]
    reobj = re.compile(r'<a href="[\d\D]*?" class="">([\d\D]*?)</a>')
    for match in reobj.finditer(html):
        bt=match.group(1)
        list4.append(bt)
    return list4

#获取分数
def get_fs(html):
    list5=[]
    reobj = re.compile(r"</a></td><td>([\d\D]*?)</td>")
    for match in reobj.finditer(html):
        fs=match.group(1)
        list5.append(fs)
    return list5

#获取通过数
def get_tgs(html):
    list6=[]
    reobj = re.compile(r"</a></td><td>[\d\D]*?</td><td>([\d\D]*?)</td>")
    for match in reobj.finditer(html):
        tgl=match.group(1)
        list6.append(tgl)
    return list6

#获取提交数
def get_tjs(html):
    list7=[]
    reobj = re.compile(r"</a></td><td>[\d\D]*?</td><td>[\d\D]*?</td><td>([\d\D]*?)</td>")
    for match in reobj.finditer(html):
        tjs=match.group(1)
        list7.append(tjs)
    return list7

#获取通过率
def get_tgl(html):
    list8=[]
    reobj = re.compile(r"</a></td><td>[\d\D]*?</td><td>[\d\D]*?</td><td>[\d\D]*?</td><td>([\d\D]*?)</td></tr>")
    for match in reobj.finditer(html):
        tgl=match.group(1)
        list8.append(tgl)
    return list8

urls = [("https://pintia.cn/problem-sets/1111652100718116864/problems/type/6","函数题"),("https://pintia.cn/problem-sets/1111652100718116864/problems/type/7","编程题")]
result=[]
for url,category in urls:
    html=get_html(url)
    bh=get_bh(html)
    lj=get_lj(html)
    bt=get_bt(html)
    fs=get_fs(html)
    tgs=get_tgs(html)
    tjs=get_tjs(html)
    tgl=get_tgl(html)
    for a,b,c,d,e,f,g in zip(bh,lj,bt,fs,tgs,tjs,tgl):
        t=(category,a,b,c,d,e,f,g)
        result.append(t)

# %%
#获取连接内的数据
def get_sj(html1):
    list9=[]
    reobj = re.compile(r'<div class="problem_Yd8rq p-3 mb-3 background-grey-1"><div class="ques-view">([\d\D]*?)</div><div class="problemInfo_OZ-Rv">')
    for match in reobj.finditer(html1):
        sj=match.group()
        list9.append(sj)
    return list9

final_result=[]
#调用上面的result内的数据，获取其中的链接，打开，获取数据
for i in result:
    url1=i[2]
    driver=webdriver.Chrome()
    driver.get(url1)
    time.sleep(5)
    html1=driver.page_source
    sj=get_sj(html1)         #连接中的内容
    sj1=str(sj)
    z=(i[0],i[1],i[2],i[3],i[4],i[5],i[6],i[7],sj1)   #合并到z中
    final_result.append(z)
    driver.close()

# %%
from pony.orm import *


db = Database()   #创建数据库对象


class Ttitle(db.Entity):
    lx = Optional(str)
    bh = PrimaryKey(str, auto=True)
    url = Optional(str)
    bt = Optional(str)
    fs = Optional(str)
    tgs = Optional(str)
    tjs = Optional(str)
    tgl = Optional(str)
    sj = Optional(str)

# %%
db.bind(provider='sqlite', filename='c:/code2020/ggg.sqlite')

db.generate_mapping(create_tables=True)
#将实体映射到数据库表,参数create_tables = True表示如果实体指向的表尚不存在，则使用CREATE TABLE命令创建它们。必须在调用generate_mapping（）方法之前定义连接到数据库的所有实体。

set_sql_debug(True)
# Out:
# GET NEW CONNECTION
# RELEASE CONNECTION
# GET CONNECTION FROM THE LOCAL POOL
# PRAGMA foreign_keys = false
# BEGIN IMMEDIATE TRANSACTION
# CREATE TABLE "Ttitle" (
#   "lx" TEXT NOT NULL,
#   "bh" TEXT NOT NULL PRIMARY KEY,
#   "url" TEXT NOT NULL,
#   "bt" TEXT NOT NULL,
#   "fs" TEXT NOT NULL,
#   "tgs" TEXT NOT NULL,
#   "tjs" TEXT NOT NULL,
#   "tgl" TEXT NOT NULL,
#   "sj" TEXT NOT NULL
# )
#
# SELECT "Ttitle"."lx", "Ttitle"."bh", "Ttitle"."url", "Ttitle"."bt", "Ttitle"."fs", "Ttitle"."tgs", "Ttitle"."tjs", "Ttitle"."tgl", "Ttitle"."sj"
# FROM "Ttitle" "Ttitle"
# WHERE 0 = 1
#
# COMMIT
# PRAGMA foreign_keys = true
# CLOSE CONNECTION

# %%
for x in final_result:
    s = Ttitle(lx=x[0],bh=x[1],url=x[2],bt=x[3],fs=x[4],tgs=x[5],tjs=x[6],tgl=x[7],sj=x[8])
    db.commit()
# Out:
# GET NEW CONNECTION
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['函数题', '第6章函数-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459776', '使用函数求特殊a串数列和', '10', '1134', '3642', '0.31', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['函数题', '第6章函数-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459777', '使用函数求素数和', '20', '939', '2595', '0.36', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['函数题', '第6章函数-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459778', '使用函数统计指定数字的个数', '20', '840', '1577', '0.53', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['函数题', '第6章函数-4', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459779', '使用函数输出指定范围内Fibonacci数的个数', '20', '743', '1648', '0.45', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['函数题', '第6章函数-5', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459781', '使用函数求余弦函数的近似值', '20', '647', '1707', '0.38', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['函数题', '第6章函数-6', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459789', '缩写词', '20', '709', '1352', '0.52', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第1章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653039147499521', '从键盘输入两个数，求它们的和并输出', '30', '4304', '10901', '0.39', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第1章-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653039147499522', '从键盘输入三个数到a,b,c中，按公式值输出', '30', '3568', '14082', '0.25', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第1章-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653039147499520', '输出“Python语言简单易学”', '10', '2885', '10162', '0.28', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467981', '计算 11+12+13+...+m', '30', '3230', '13318', '0.24', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467968', '计算分段函数[1]', '10', '2758', '11879', '0.23', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467971', '阶梯电价', '15', '2366', '9612', '0.25', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-4', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467975', '特殊a串数列求和', '20', '2344', '7794', '0.30', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-5', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467970', '求奇数分之一序列前N项和', '15', '2076', '5744', '0.36', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-6', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467973', '求交错序列前N项和', '15', '1936', '4492', '0.43', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-7', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467980', '产生每位数字相同的n位数', '30', '2020', '5889', '0.34', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-8', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467979', '转换函数使用', '30', '1884', '3983', '0.47', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-9', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467974', '比较大小', '10', '1804', '5068', '0.36', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-10', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467969', '输出华氏-摄氏温度转换表', '15', '1763', '8308', '0.21', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-11', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467972', '求平方与倒数序列的部分和', '15', '1472', '2731', '0.54', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-12', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467976', '输出三角形面积和周长', '15', '1557', '5205', '0.30', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-13', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467977', '分段计算居民水费', '10', '1401', '2373', '0.59', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第2章-14', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1111653447408467978', '求整数段和', '15', '1569', '6742', '0.23', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180308', '3-1.大于身高的平均值', '10', '1494', '3127', '0.48', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180309', '查验身份证', '15', '1192', '4445', '0.27', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180307', '输出字母在字符串中位置索引', '20', '1284', '2263', '0.57', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-4', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180288', '查找指定字符', '15', '1191', '2914', '0.41', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-5', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180289', '字符转换', '15', '1217', '3359', '0.36', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-6', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180290', '求整数序列中出现次数最多的数', '15', '1130', '3686', '0.31', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-7', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180291', '求最大值及其下标', '20', '1089', '2378', '0.46', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-8', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180292', '字符串逆序', '15', '1144', '1632', '0.70', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-9', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180293', '字符串转换成十进制整数', '15', '933', '4510', '0.21', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-10', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180294', '统计大写辅音字母', '15', '1006', '1822', '0.55', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-11', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180295', '字符串排序', '20', '1042', '1649', '0.63', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-12', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180296', '求整数的位数及各位数字之和', '15', '975', '1354', '0.72', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-13', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180297', '字符串替换', '15', '936', '1629', '0.57', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-14', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180298', '字符串字母大小写转换', '15', '974', '1762', '0.55', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-15', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180299', '统计一行文本的单词个数', '15', '950', '1599', '0.59', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-16', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180300', '删除重复字符', '20', '986', '1659', '0.59', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-17', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180301', '删除字符', '30', '993', '4122', '0.24', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-18', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180302', '输出10个不重复的英文字母', '30', '979', '2948', '0.33', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-19', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180303', '找最长的字符串', '15', '865', '1439', '0.60', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-20', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180304', '逆序的三位数', '10', '908', '1548', '0.59', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-21', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180305', '判断回文字符串', '15', '891', '2136', '0.42', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第3章-22', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163031535431180306', '输出大写英文字母', '15', '840', '1545', '0.54', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477952', '生成3的乘方表', '15', '868', '1982', '0.44', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477954', '统计素数并求和', '20', '917', '2825', '0.32', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477955', '猴子吃桃问题', '15', '844', '1163', '0.73', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-4', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477956', '验证“哥德巴赫猜想”', '20', '876', '3585', '0.24', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-5', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477953', '求e的近似值', '15', '807', '1774', '0.45', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-6', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477957', '输出前 n 个Fibonacci数', '15', '855', '2811', '0.30', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-7', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477958', '统计学生平均成绩与及格人数', '15', '756', '3946', '0.19', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-8', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477959', '求分数序列前N项和', '15', '711', '1167', '0.61', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-9', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477960', '查询水果价格', '15', '694', '1666', '0.42', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-10', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477961', '最大公约数和最小公倍数', '15', '725', '1360', '0.53', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-11', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477962', '判断素数', '20', '790', '1410', '0.56', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-12', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477978', '求满足条件的斐波那契数', '30', '746', '1014', '0.74', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-13', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477980', '求误差小于输入值的e的近似值', '20', '666', '1213', '0.55', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-14', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477979', '统计字符', '15', '633', '1527', '0.41', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-15', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477963', '换硬币', '20', '629', '1355', '0.46', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-16', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477964', 'jmu-python-判断是否构成三角形', '10', '653', '1007', '0.65', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-17', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477965', '水仙花数（20 分）', '20', '716', '1261', '0.57', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-18', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477976', '猴子选大王', '20', '627', '1014', '0.62', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-19', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477966', '矩阵运算', '20', '607', '1020', '0.60', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-20', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477967', '求矩阵各行元素之和', '15', '604', '777', '0.78', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-21', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477968', '判断上三角矩阵', '15', '584', '1397', '0.42', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-22', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477969', '找鞍点', '20', '570', '1727', '0.33', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-23', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477971', '求矩阵的局部极大值', '15', '483', '913', '0.53', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-24', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477972', '打印九九口诀表', '15', '590', '1320', '0.45', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-25', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477970', '输出三角形字符阵列', '15', '524', '844', '0.62', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-26', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477973', '求1!+3!+5!+……+n!', '10', '595', '886', '0.67', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-27', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477974', '二维数组中每行最大值和每行和', '10', '500', '909', '0.55', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-28', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477975', '矩阵转置', '10', '520', '844', '0.62', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-29', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477977', '找出不是两个数组共有的元素', '20', '549', '1285', '0.43', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第4章-30', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163032889524477981', '找完数', '20', '607', '2552', '0.24', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829066', '输出星期名缩写', '70', '675', '1071', '0.63', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829056', '图的字典表示', '20', '480', '641', '0.75', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829058', '四则运算（用字典实现）', '30', '579', '1072', '0.54', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-4', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829059', '分析活动投票情况', '20', '623', '1773', '0.35', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-5', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829060', '统计字符出现次数', '20', '614', '885', '0.69', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-6', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829061', '统计工龄', '20', '556', '1043', '0.53', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-7', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829062', '列表去重', '40', '695', '2102', '0.33', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-8', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829063', '能被3,5和7整除的数的个数（用集合实现）', '30', '584', '773', '0.76', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-9', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829064', '求矩阵鞍点的个数', '30', '447', '763', '0.59', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-10', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829065', '两数之和', '30', '541', '972', '0.56', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第5章-11', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163034891574829057', '字典合并', '40', '515', '1173', '0.44', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459780', '输入列表，求列表元素和(eval输入应用）', '10', '551', '769', '0.72', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-2', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459788', '一帮一', '15', '464', '830', '0.56', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-3', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459782', '列表或元组的数字元素求和', '20', '513', '941', '0.55', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-4', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459783', '列表数字元素加权和(1)', '40', '488', '977', '0.50', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-5', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459784', '列表元素个数的加权和(1)', '40', '460', '735', '0.63', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-6', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459785', '求指定层的元素个数', '40', '458', '1291', '0.35', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-7', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459786', '找出总分最高的学生', '15', '453', '708', '0.64', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第6章-8', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163035698160459787', '*输出全排列（选作）', '20', '460', '641', '0.72', '[]']
#
# COMMIT
# BEGIN IMMEDIATE TRANSACTION
# INSERT INTO "Ttitle" ("lx", "bh", "url", "bt", "fs", "tgs", "tjs", "tgl", "sj") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
# ['编程题', '第7章-1', 'https://pintia.cn/problem-sets/1111652100718116864/problems/1163036357031092224', '词频统计', '30', '513', '1731', '0.30', '[]']
#
# COMMIT
