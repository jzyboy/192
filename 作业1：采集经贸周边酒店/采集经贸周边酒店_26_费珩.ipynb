# %%
from selenium import webdriver
driver=webdriver.Chrome()
url = 'https://map.baidu.com/search/%E9%85%92%E5%BA%97/@13401816.6,3523321.62,17z?querytype=nb&r=1000&wd=%E9%85%92%E5%BA%97&nb_x=13401816.60&nb_y=3523321.62&uid=7a0cb8c0d67a634683a00c28&b=(13400809.909611505,3522782.19066226;13402823.09336229,3524093.869264365)&l=17&gr_radius=1000&pn=0&device_ratio=2&da_src=shareurl'
driver.get(url)
html=driver.page_source

# %%
import re
import pandas as pd
import time
list1=[]
list2=[]
list3=[]
html = driver.page_source
for i in range(2):
    html = driver.page_source
    reobj = re.compile(r'<a href="javascript:void\(0\)"[\d\D]*?data-index=[\d\D]*?data-detail-code="list_page">([\d\D]*?)</a>[\d\D]*?<span>                    [\d\D]*?<i class="seperate">\|</i>([\d\D]*?)</span>[\d\D]*?<div class="row addr">                <span class="n-grey" title="([\d\D]*?)">', re.MULTILINE)
    for match in reobj.finditer(html):
	# match start: match.start()
	# match end (exclusive): match.end()
	# matched text: match.group()
        name=match.group(1)
        leixing=match.group(2)
        dizhi=match.group(3)
        list1.append(name)
        list2.append(leixing)
        list3.append(dizhi)
    driver.find_element_by_link_text(u"下一页>").click()
    import time
    time.sleep(5)
pd.DataFrame({'店名':list1,'类型':list2,'地址':list3})
# Out:
#                  店名                   类型  \
# 0           浙江供销客房部   酒店
# 1           TEL茶砚酒店  舒适型
# 2            后街主题酒店  经济型
# 3              沙城旅馆  经济型
# 4            杭州暖巢公寓   宾馆
# 5    速8酒店(杭州下沙金沙居店)  经济型
# 6              潮人旅馆  经济型
# 7   杭州子行千里公寓(NO.3店)  经济型
# 8      杭州陌上花开2019公寓   酒店
# 9          杭州钱塘江语公寓  经济型
# 10           江畔一家公寓  经济型
#
#                                            地址
# 0                                      杭州市江干区
# 1                             学源街239号浙江经贸学院北门
# 2                   浙江省杭州市江干区下沙学正街559号(金沙居B座)
# 3           杭州市江干区２５号大街与６号大街交叉路口往北约100米(金沙学府)
# 4                        浙江省杭州市江干区经济开发区宝龙城市广场
# 5                        杭州市江干区学正街567号金沙居B座3层
# 6                 杭州市江干区２５号大街与学正街交叉路口南侧(金沙学府)
# 7                               25号大街(宝龙城市广场)
# 8                           浙江省杭州市江干区宝龙城市广场二期
# 9                                      宝龙城市广场
# 10  杭州江干区下沙宝龙城市广场17幢(杭州下沙宝龙城市广场2号大街与25号大街交叉口)
