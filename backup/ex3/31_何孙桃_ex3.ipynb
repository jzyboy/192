# %%
from selenium import webdriver
driver=webdriver.Chrome()
url = 'https://www.baidu.com/s?wd=%E6%98%8E%E6%98%9F&rsv_spt=1&rsv_iqid=0xbe4b76860031fb66&issp=1&f=8&rsv_bp=1&rsv_idx=2&ie=utf-8&rqlang=&tn=baiduhome_pg&ch=&rsv_enter=1&rsv_dl=ib&inputT=2978'
driver.get(url)

# %%
driver.find_element_by_xpath("//div[@id='1']/div/div/div/div[2]/p/span[4]").click()
driver.find_element_by_xpath("//div[@id='1']/div/div/div/div[2]/p[2]/span[3]").click()

# %%
#定义空列表list1
list1=[]
#获取第一页的源代码并采集，放入元组。列表
html = driver.page_source
reobj = re.compile(r'<img class="c-img c-img4" src="([\d\D]*?)"></a></p><p class="c-gap-top-small"><a href="([\d\D]*?)" title="([\d\D]*?)"', re.MULTILINE)
for match in reobj.finditer(html):
    #print("姓名:",match.group(3),"图片链接:",match.group(1),"网页链接:https://www.baidu.com",match.group(2))
    a=match.group(3)
    b=match.group(1)
    c=match.group(2)
    x=[a,b,c]
    list1.append(x)
#等待    
    time.sleep(2)
#存储为csv格式，中文编码，写入文字
import codecs
f = codecs.open(r"c:\code2020\result.csv","w","utf-8-sig")
f.write("姓名,图片链接,图片链接,网页链接\n")
import re
import time
#循环提取第一页之后的数据并放入元组、列表
for i in range(330):#循环次数不能超过数据页数，否则会报错
    driver.find_element_by_xpath("//div[@id='1']/div/div/div[2]/div[2]/p/span[6]").click()
    time.sleep(2) 
    html = driver.page_source
    reobj = re.compile(r'<img class="c-img c-img4" src="([\d\D]*?)"></a></p><p class="c-gap-top-small"><a href="([\d\D]*?)" title="([\d\D]*?)"', re.MULTILINE)
    for match in reobj.finditer(html):
        #print("姓名:",match.group(3),"图片链接:",match.group(1),"网页链接:https://www.baidu.com",match.group(2))
        a=match.group(3)
        b=match.group(1)
        c=match.group(2)
        x=[a,b,c]
        list1.append(x)
    
#循环录入数据到csv表格    
print(list1)
for j in range(len(list1)):
    k=list1[j]
    f.write(k[0]+","+k[1]+","+k[2]+"\n")
f.close()
# Out:
# [['宋茜', 'https://dss1.baidu.com/6ONXsjip0QIZ8tyhnq/it/u=19628239,2133979713&amp;fm=58&amp;s=543407743E6358056C0C6DCB030070BB', '/s?wd=%E5%AE%8B%E8%8C%9C&amp;rsv_idx=2&amp;tn=baiduhome_pg&amp;usm=6&amp;ie=utf-8&amp;rsv_cq=%E6%98%8E%E6%98%9F&amp;rsv_dl=0_left_exactqa_28266'], ['刘诗诗', 'https://dss1.baidu.com/6ONXsjip0QIZ8tyhnq/it/u=4175403331,1227841461&amp;fm=58&amp;s=DA88AF476E23768C991018B303008060', '/s?wd=%E5%88%98%E8%AF%97%E8%AF%97&amp;rsv_idx=2&amp;tn=baiduhome_pg&amp;usm=6&amp;ie=utf-8&amp;rsv_cq=%E6%98%8E%E6%98%9F&amp;rsv_dl=0_left_exactqa_28266'], ['周笔畅', 'https://dss0.baidu.com/6ONWsjip0QIZ8tyhnq/it/u=3786245439,701599185&amp;fm=58&amp;s=F7B020625C336694340C77C70300F0AF', '/s?wd=%E5%91%A8%E7%AC%94%E7%95%85&amp;rsv_idx=2&amp;tn=baiduhome_pg&amp;usm=6&amp;ie=utf-8&amp;rsv_cq=%E6%98%8E%E6%98%9F&amp;rsv_dl=0_left_exactqa_28266'], ['萧亚轩', 'https://dss2.baidu.com/6ONYsjip0QIZ8tyhnq/it/u=1447146971,1918224325&amp;fm=58&amp;s=9B848746CE3BBAD41E75AEA30300A007', '/s?wd=%E8%90%A7%E4%BA%
# ...
